# %%
#PYTHON

# %% [markdown]
# ## QUES 1 ) Explain the key features of python that make it a popular choice for programming
#
# python is a popular programming language for saveral reasons.here are some key features that makes python a preferred choice:
#
# 1*Readability*: Python emphasizes readability and uses simple and clean syntax,making it easier to understand and write code.This feature is particularly beneficial for beginners and experienced programmer alike.
#
# 2*Versatility*: Python is a versatile language that can be used for a wide range of applications,ncluding web development,data analysis,artificial intelligence,scientific computing,automation,and more.Its flexibilty allows developers to work on diverse projects.
#
# 3*Platform independece*: Python is a platform-independent language,which means that code written in Python can run on various operating systems without modification.This cross-platfrom compatibility makes Python an aatractive choice for developers working in different environment.
#
# Another aspects that makes Python a popular choice for programming is its strong support or object-oriented programming (OOP) principles.Pyhthon allows developers to create reusable and organized code through classes and objects,promoting modularity and code resuability.This OOP support simplifies complex problems by breaking them down into smaller,more manageable components,enhancing code structure and maintainability.

# %% [markdown]
# ## QUES 2) Describe the role of predefined keywords in python and provide examples of how they are used in Program
#
# Predefined keywords in Python plays crucial role in defining the syntax and structure of the language.These keywordsare reserved and have a specific meanings assigned to them,which cannot be used for any other purpose within the code.Here are some examples of predefined keywords in Python and how they are used in a program:
# #Example python
# 1*if,elif,else*:These keywords are used for condtional statements in Python.They control the flow of the program based on certain conditons.Here's an example:
# x = 10
#
# if x > 5:
#
#   print(x is greater than 5")
#
#   elif x == 5:
#
#   print("x is equal to 5")
#
#   else:
#
#   print("x is less than 5")
#
# 2*for,while*:These keywords are used for looping construct in Python.They help in iterating over sequemces or executing a block of code repeatedly.
# Example python
#           for i in range(5):
#
#   print(i)
#
# These examples showcase how predefined keywords in Python are intregal to the language's syntax and funcrionality.

# %% [markdown]
# ## QUES 3) Compare and contrast mutable and immutable objects in Python with examples
#
# 1*Mutable objects*:Mutable objects can be altered after creation,meaning their content can be modified.
# -chanfge made to mutable objects directly affects the object itself.
# Examples of mutable objects in Python include lists,dictionaries,and sets
#
# Examples of amutable objects(list)
# python
# my_list=[1.2,3]
# print("Original List:",my_list)
#
# my_list.append(4)
# print("Modified List:",my_list)
#
# 2*Immutable objects*Immutable objects cannot be changed once they are created;any operation that modifies an immutable object results in a creation of a new object.
# -immutable objects preserve their origina value.
# -Exampes of immutable objects in python include integer,dtrings,tuples,and frozensets.
#
# Exaples of an immutable objects(integer):
# my_num = 5
# print("Original Number:";my_num)
#
# my_num += 1
# print("Modified Number:",my_num)
#
#
#
#      *COMPARISION*
#
# 1)*Mutability*:Mutable objects can be changed,while immutable objects cannot be changed.
#
# 2)*Memory Manangement*:immutable object are more memory-efficient as they do not change in place,resulting in less memory fragmentation.
#
# 3)*Use Cases*:Mutable objects are suitable for scenarios where the data needs to be modified frequently,while immutable objects are preferred for data that should remain constant.
#
#       *CONTRAST*
#
# 1)*Behavior*:Mutable objects are modified in place,while operations on immutable objects create new objects.
#
# 2)*State*:Mutable objects allow for changes to their state,while immutable objects maintain their original state.
#
# 3)*Memory Efficiency*:Immutable objects are more money-efficient due to their immutability,while mutable objects may require more money due to potential changes.

# %% [markdown]
# ## QUES 4) Discuss the different types of operators in Python and provide examples of how they are used
#
# Here are the main types of operators in Python along with examples of how they are used
#
# 1)*Arithmatic Operator*:These operstors are used for mathematical operations.
# -Examples: +(addition), -(subtraction), *(multiplication), /(division), %(modulus), **(exponentiation).
#
# Example
#
# python
#
# a = 10
#
# b = 3
#
# print(a+b) #addition
#
# print(a-b) #subtration
#
# print(a*b) #multiplication
#
# print(a/b) #division
#
# print(a%b) #modulus
#
# print(a**b) #exponentiation
#
#
# 2)*Comparision*(relational)Operator:These operators are used to compare values.
# -Examples: ==(equal), !=(not equal),>(greater than),<(less than),>=(greater than or equal to),<=(less than or equal to).
#
# Example:
# python
# x = 5
#
# y = 3
#
# print(x==y) #Equal
#
# print(x!=y) #Not equal
#
# print(x>y)  #Greater than
#
# print(x<y)  #Less than
#
# print(x>=y) #Greater than or equal to
#
# print(x<=y) #Less than or equal to
#
#
# 3)*Logical Operator*:These operators are used to combine conditional statements.
# -Examples:and (logical AND), or (logical OR), not (logical NOT).
# Examples:
# python
# p = True
#
# q = False
#
# print(p and q) #Logical AND
#
# print(p or q)  #Logical OR
#
# print(not p)   #Logical NOT
#
#
# 4)*Assignment Operator*:These operators are used to assign values to variables.
# -Examples: = (assignment), +=(addition assignment), -=(subtraction assignment), *=(multiplication assignment),/=(division assignment).
# Example:
# python
# num = 10
#
# num += 5 #Equivalent to num = num + 5
#
# print(num)
#
#
# 5)*Bitwise Operator*:These operators perfrom bit-level operations.
# -Examples: &(bitwise AND), |(bitwise OR), ^(bitwise XOR), <<(left shift), >>(right shift).
#
# Example
#
# python
#
# a = 2 # 10 in binary
#
# b = 3 # 11 in binary
#
# print(a&b) # bitwise AND
#
# print(a|b) # bitwise OR

# %% [markdown]
# ## QUES 5) Explain the concept of type casting in Python with examples
#
# In Python, type casting refers to the conversion of one data type to another. This process allows you to change the data type of a variable or value. Here's an explanation of type casting with examples:
#
# 1. *Implicit Type Conversion*:
#    - Python automatically converts data types in certain situations, such as when performing operations between different types.
#
#    Example:
#    python
#    num_int = 10
#    num_float = 5.5
#    result = num_int + num_float  # Python implicitly converts num_int to a float before performing the addition
#    print(result)  # Output: 15.5
#
#
# 2. *Explicit Type Conversion*:
#    - You can explicitly convert data types using predefined functions like int(), float(), str(), etc.
#
#    Example:
#    python
#    num_str = "50"
#    num_int = int(num_str)  # Convert the string "50" to an integer
#    print(num_int)  # Output: 50
#
#    num_float = float(num_int)  # Convert the integer 50 to a float
#    print(num_float)  # Output: 50.0
#
#
# 3. *Type Casting between Different Data Types*:
#    - You can convert data types between integers, floats, and strings.
#
#    Example:
#    python
#    num_int = 100
#    num_str = str(num_int)  # Convert the integer 100 to a string
#    print(num_str)  # Output: "100"
#
#    num_float = float(num_str)  # Convert the string "100" to a float
#    print(num_float)  # Output: 100.0
#
#
# 4. *Handling Errors during Type Casting*:
#    - Type casting can raise errors if the conversion is not possible (e.g., converting a string that is not a number to an integer).
#
#    Example:
#    python
#    num_str = "hello"
#    try:
#        num_int = int(num_str)  # Trying to convert a non-numeric string to an integer will raise a ValueError
#    except ValueError as e:
#        print("Error:", e)
#
#
# Type casting is a useful technique in Python to manipulate data types and perform operations that require values of different types. If you have more questions or need further examples

# %% [markdown]
# ## QUES 6) How do conditional statements work in Python? Illustrate with examples
#
# Hey there! Conditional statements in Python allow you to make decisions in your code based on certain conditions. The most common conditional statements in Python are if, elif (short for else if), and else.
#
# Here's a simple example to illustrate how they work:
#
# python
# Example 1: Using if statement
#
# x = 10
#
# if x > 5:
#
#    print("x is greater than 5")
#
#
# In this example, if the condition x > 5 is true, the message "x is greater than 5" will be printed.
#
# Now, let's look at an example with if, elif, and else statements:
#
# python
# Example 2: Using if, elif, and else statements
#
# y = 20
#
# if y < 10:
#
#   print("y is less than 10")
#
#   elif y == 10:
#
#   print("y is equal to 10")
# else:
#     print("y is greater than 10")
#
#
# In this case, if y is less than 10, it will print "y is less than 10". If y is exactly 10, it will print "y is equal to 10". If neither of these conditions is met, it will print "y is greater than 10".
#
# These conditional statements help you control the flow of your program based on different situations.

# %% [markdown]
# ## QUES 7) Describe the different types of loops in Python and their use cases with examples
#
# In Python, there are mainly two types of loops: for loops and while loops. Each type of loop has its use cases and can be helpful in different situations.
#
# 1. *For Loop*:
#    - Use a for loop when you know the number of iterations in advance or when you want to iterate over a sequence (like a list, tuple, string, etc.).
#    - Here's an example of a for loop:
#
# python
#
# Example of a for loop
#
# fruits = ["apple", "banana", "cherry"]
#
# for fruit in fruits:
#
#    print(fruit)
#
#
# In this example, the for loop iterates over each element in the fruits list and prints each fruit.
#
# 2. *While Loop*:
#    - Use a while loop when you want to iterate based on a condition that needs to be true.
#    - Here's an example of a while loop:
#
# python
#
#   Example of a while loop
#
#   count = 0
#
#   while count < 5:
#
#   print(count)
#
#   count += 1
#
#
# In this example, the while loop will keep executing as long as the count is less than 5. It prints the value of count and increments it by 1 in each iteration.
#
# Both for and while loops are essential in programming and help in automating repetitive tasks or processing elements in a sequence.
